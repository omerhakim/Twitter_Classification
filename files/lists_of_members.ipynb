# %%
#http://www.tweetcongress.org/tweeters

# %% [markdown]
# ## Democrats

# %%
#ALABAMA
AL = ['RepTerriSewell','sendougjones']

#Alaska
AK = []

#AMERICAN SAMOA
AS=[]

#ARIZONA
AZ= ['RepRubenGallego','RepKirkpatrick','RepraulGrijalva','repohalleran','SenatorSinema','RepGregStanton']

#ARKANSAS
AR=[]

#CALIFORNIA
CA = ['SenFeinstein','RepMarkTakano','RepJudyChu','RepJimCosta','RepSusanDavis','SenKamalaHarris','RepJimmyGomez',
      'RepAnnaEshoo','RepGaramendi','RepKarenBass','DorisMatsui','RepMcNerney','GraceNapolitano','RepRoybalAllard',
      'RepAdamSchiff','BradSherman','RepLindaSanchez','RepThompson','RepMaxineWaters','RepHuffman','RepBera',
      'RepSwalwell','RepCardenas','CongressmanRuiz','RepLowenthal','RepJuanVargas','RepScottPeters','RepDeSaulnier',
      'reppeteaguilar','RepTedLieu','NormaJTorres','RepRoKhanna','RepJimmyPanetta','RepCarbajal','RepBarragan',
      'reploucorrea','JuliaBrownley26','RepJoshHarder','RepTjCox','RepKatieHill','RepGilCisneros','RepKatiePorter',
      'RepHarley','RepMikeLevin','SpeakerPelosi','RepBarbaraLee','RepZoeLofgren','RepSpeier']

#COLORADO
CO = ['SenatorBennet','RepPerlmutter','RepDianaDeGette','RepJoeNeguse','RepJasonCrow']

#CONNECTICUT
CT = ['RepJoeCourtney','RosaDeLauro','JAHimes','RepJohnLarson','senmurphyoffice','RepJahanaHayes','SenBlumenthal']

#DELAWARE
DE= ['SenatorCarper','ChrisCoons','RepLBR']

#DISTRICT OF COLUMBIA
DC=['EleanorNorton']

#FLORIDA
FL=['USRepKCastor','RepHastingsFL','RepDWStweets','RepWilson','RepLoisFrankel','RepStephMurphy','RepDarrenSoto',
    'RepValDemings','repcharliecrist','RepDMP','RepShalala','RepAlLawsonJr','RepTedDeutch']

#GEORGIA
GA = ['RepHankJohnson','RepJohnLewis','replucymcbath','RepDavidScott','SanfordBishop']

#HAWAII
HI=['SenBrianSchatz','TulsiPress','RepEdCase','MazieHirono']

#IDAHO
ID = []

#ILLINOIS
IL=['SenatorDurbin','RepRobinKelly','RepDannyDavis','RepLipinski','RepMikeQuigley','JanSchakowsky','RepBobbyRush',
    'RepBillFoster','SenDuckworth','RepCheri','repschneider','congressmanraja','RepChuyGarcia',
    'RepCasten','RepUnderwood']

#INDIANA
IN=['RepAndreCarson','RepVisclosky']

#IOWA
IA = ['DaveLoebsack','RepFinkenauer','RepCindyAxne']

#KANSAS
KS = ['RepDavids']

#KENTUCKY
KY=['RepJohnYarmuth']

#LOUISIANA
LA = ['RepRichmond']

#MAINE
ME = ['ChelliePingree','SenAngusKing','repgolden']

#MARYLAND
MD = ['SenatorCardin','RepCummings','LeaderHoyer','Call_Me_Dutch','RepSarbanes','RepAnthonyBrown','repraskin',
      'repdavidtrone','ChrisVanHollen']

#MASSACHUSETTS

MA = ['RepKClark','RepStephenLynch','SenMarkey','RepMcGovern','SenWarren','RepJoeKennedy','teammoulton',
      'RepLoriTrahan','RepPressley','USRepKeating','RepRichardNeal']

#MICHIGAN
MI = ['SenStabenow','SenGaryPeters','RepDanKildee','RepDebDingell','RepLawrence','RepSlotkin','RepAndyLevin',
      'RepHaleyStevens','RepRashida']

#MINNESOTA
MN = ['BettyMcCollum04','SenTinaSmith','RepAngieCraig','Ilhan Omar','SenAmyKlobuchar','RepDeanPhillips']

#MISSISSIPPI
MS=['BennieGThompson']

# MISSOURI
MO = ['RepCleaver']

# MONTANA
MT = ['SenatorTester']

# NEBRASKA
NE = []

# NEVADA
NV = ['RepDinaTitus','SenJackyRosen','sencortezmasto']

# NEW HAMPSHIRE
NH = ['SenatorShaheen','Senatorhassan','RepAnnieKuster','RepChrisPappas']

# NEW JERSEY
NJ = ['BillPascrell','RepDonaldPayne','SenBooker','DonaldNorcross','RepBonnie','RepJoshG',
      'CongressmanJVD','RepAndyKimNJ','RepMalinowski','RepSherrill','RepSires']

# NEW MEXICO
NM = ['SenatorTomUdall','RepBenRayLujan','RepDebHaaland','RepTorresSmall','MartinHeinrich']

# NEW YORK
NY = ['GillibrandNY','RepYvetteClarke','RepEliotEngel','RepBrianHiggins','NitaLowey','RepMaloney',
      'RepJerryNadler','SenSchumer','RepJoseSerrano','RepPaulTonko','NydiaVelazquez','RepGraceMeng',
      'RepJeffries','RepSeanMaloney','RepKathleenRice','RepTomSuozzi','RepEspaillat','RepJoeMorelle',
      'RepMaxRose','RepAOC','repdelgado','RepBrindisi','RepGregoryMeeks']

# NORTH CAROLINA
NC = ['GKButterfield','RepDavidEPrice','RepAdams']

# NORTH DAKOTA
ND = []

# NORTHERN MARIANA ISLANDS

MP = ['Kilili_Sablan']

# OHIO
OH = ['SenSherrodBrown','RepMarciaFudge','RepMarcyKaptur','RepTimRyan','RepBeatty']

# OKLAHOMA
OK = ['RepKendraHorn']

# OREGON
OR = ['SenJeffMerkley','BlumenauerMedia','RepPeterDeFazio','RepSchrader','RonWyden','RepBonamici']

# PENNSYLVANIA
PA = ['SenBobCasey','RepDwightEvans','USRepMikeDoyle','RepCartwright','CongBoyle','RepConorLamb','RepMGS',
      'RepSusanWild','RepDean','RepHoulahan']

# PUERTO RICO
PR = []

# RHODE ISLAND
RI = ['SenWhitehouse','SenJackReed','RepCicilline','JimLangevin']

# SOUTH CAROLINA
SC = ['WhipClyburn','RepCunningham']

# SOUTH DAKOTA
SD = []

# TENNESSEE
TN = ['RepCohen','RepJimCooper']

# TEXAS
TX = ['RepVeasey','RepFilemonVela','RepLloydDoggett','RepAlGreen','JacksonLeeTX18','RepCuellar','JoaquinCastrotx',
      'RepGonzalez','RepEBJ','RepFletcher','RepEscobar','RepSylviaGarcia','RepColinAllred','','','','']

# UTAH
UT = ['RepBenMcAdams']

# VERMONT
VT = ['SenatorLeahy','PeterWelch','SenSanders']

# VIRGIN ISLANDS
VI = ['staceyplaskett']

# VIRGINIA
VA = ['GerryConnolly','MarkWarner','RepDonBeyer','BobbyScott','RepMcEachin','RepElaineLuria','RepSpanberger',
      'RepWexton']

# WASHINGTON
WA = ['SenatorCantwell','RepRickLarsen','PattyMurray','RepAdamSmith','RepDelBene','RepDerekKilmer',
      'RepDennyHeck','RepKimSchrier','RepJayapal']

# WEST VIRGINIA
WV = ['Sen_JoeManchin']

# WISCONSIN
WI = ['SenatorBaldwin','RepRonKind','RepGwenMoore','RepMarkPocan']

# WYOMING
WY = []

# %%
Dems = AL +AK+ AS+ AZ+ AR+ CA+ CO+ CT+ DE+ DC+ FL+ GA+ HI+ ID +IL+ IN+ IA+ KS+ KY+ LA+ ME+ MA+ MI+ MN+ MS +MO +MT +NE +NV +NH +NJ +NM +NY +NC +ND +MP +OH +OK+OR + PA + PR+ RI+ SC+ SD+ TN+ TX+ UT+ VT+ VI+ VA+ WA+ WV+ WI+ WY
len(Dems)
# Out:
# 273

# %% [markdown]
# ## Republicans

# %%
#ALABAMA
AL1 = ['Robert_Aderholt','RepMoBrooks','RepMikeRogersAL','SenShelby','RepByrne','USRepGaryPalmer']

#Alaska
AK1 = ['LisaMurkowski','RepDonYoung','SenDanSullivan']

#AMERICAN SAMOA
AS1 = ['RepAmata']

#ARIZONA
AZ1 = ['RepDavid','RepDLesko','RepGosar','SenMcSallyAZ']

#ARKANSAS
AR1 = ['JohnBoozman','RepRickCrawford','SenTomCotton','RepFrenchHill','RepWesterman','Rep_SteveWomack']

#CALIFORNIA
CA1=['RepPaulCook','KenCalvert','Rep_Hunter','RepMcClintock','RepDevinNunes','RepLaMalfa','GOPLeader']

#COLORADO
CO1 = ['RepTipton','RepKenBuck','SenCoryGardner','RepDLamborn']

#CONNECTICUT
CT1=[]

#DELAWARE
DE1 = []

#DISTRICT OF COLUMBIA
DC1=[]

#FLORIDA
FL1 = ['RepGusBilirakis','VernBuchanan','RepRooney','MarioDB','CongBillPosey','SenRubioPress','RepTedYoho',
       'RepMattGaetz','drnealdunnfl2','RepRutherfordFL','repbrianmast','RepMichaelWaltz','RepRossSpano',
       'RepGregSteube','SenRickScott','RepWebster']

#GEORGIA
GA1 = ['RepTomGraves','SenatorIsakson','RepRobWoodall','RepDougCollins','RepBuddyCarter','congressmanhice',
       'RepLoudermilk','reprickallen','AustinScottGA08','sendavidperdue','RepDrewFerguson']

#HAWAII
HI1=[]

#IDAHO
ID1 = ['SenatorRisch','MikeCrapo','CongMikeSimpson','RepRussFulcher']

#ILLINOIS
IL1 = ['RepLaHood','RepKinzinger','RepShimkus','RodneyDavis','RepBost']

#INDIANA
IN1 = ['SenToddYoung','RepWalorski','RepLarryBucshon','RepJimBanks','reptrey','RepJimBaird','RepGregPence',
       'SenatorBraun','SusanWBrooks']

#IOWA
IA1 = ['SenJoniErnst','SteveKingIA','ChuckGrassley']

#KANSAS
KS1 = ['SenPatRoberts','JerryMoran','RepMarshall','RepRonEstes','Rep_Watkins']

#KENTUCKY
KY1=['McConnellPress','RandPaul','RepThomasMassie','RepAndyBarr','RepGuthrie','RepHalRogers']

#LOUISIANA
LA1 = ['SenJohnKennedy','SteveScalise','RepAbraham','RepGarretGraves','RepClayHiggins','RepMikeJohnson',
       'SenBillCassidy']

#MAINE
ME1 = ['SenatorCollins']

#MARYLAND
MD1 = ['RepAndyHarrisMD']

#MASSACHUSETTS
MA1 = []

#MICHIGAN
MI1=['RepHuizenga','RepFredUpton','RepWalberg','RepMoolenaar','RepJackBergman','RepPaulMitchell']

#MINNESOTA
MN1 = ['RepTomEmmer','RepHagedorn','RepPeteStauber']

#MISSISSIPPI
MS1 = ['SenHydeSmith','CongPalazzo','eptrentkelly','SenatorWicker','RepMichaelGuest']

# MISSOURI
MO1 = ['RepAnnWagner','RoyBlunt','RepSamGraves','RepHartzler','USRepLong','RepBlaine',
       'RepJasonSmith','SenHawleyPress']

# MONTANA
MT1 = ['SteveDaines']

# NEBRASKA
NE1 = ['SenSasse','JeffFortenberry','RepAdrianSmith','SenatorFischer','repdonbacon']

# NEVADA
NV1 = ['MarkAmodeiNV2']

# NEW HAMPSHIRE
NH1 = []

# NEW JERSEY
NJ1 = ['RepChrisSmith']

# NEW MEXICO
NM1 = []

# NEW YORK
NY1 = ['RepPeteKing','RepChrisCollins','RepLeeZeldin','RepJohnKatko','RepStefanik','RepTomReed']

# NORTH CAROLINA
NC1 = ['RepMarkWalker','VirginiaFoxx','SenatorBurr','PatrickMcHenry','RepRichHudson',
       'RepMarkMeadows','RepHolding','RepDavidRouzer','senthomtillis','RepTedBudd']

# NORTH DAKOTA
ND1 = ['SenJohnHoeven','SenKevinCramer','RepArmstrongND']

# NORTHERN MARIANA ISLANDS

MP1 = []

# OHIO
OH1 = ['SenRobPortman','RepSteveStivers','RepMikeTurner','RepBradWenstrup','RepDaveJoyce','RepBalderson',
       'RepAGonzalez','BobLatta','RepSteveChabot','WarrenDavidson','RepBobGibbs','Jim_Jordan','RepBillJohnson']

# OKLAHOMA
OK1 = ['SenatorLankford','TomColeOK04','RepFrankLucas','RepMullin','repkevinhern','InhofePress']

# OREGON
OR1 = ['RepGregWalden']

# PENNSYLVANIA
PA1 = ['MikeKellyPA','CongressmanGT','SenToomey','RepScottPerry','repbrianfitz','RepSmucker','RepMeuser',
       'RepJohnJoyce','GReschenthaler']

# PUERTO RICO
PR1 = ['repjenniffer']

# RHODE ISLAND
RI1 = []

# SOUTH CAROLINA
SC1 = ['SenatorTimScott','RepJoeWilson','RepTomRice','RepRalphNorman','RepTimmons','GrahamBlog','RepJeffDuncan']

# SOUTH DAKOTA
SD1 = ['SenatorRounds','SenJohnThune','RepDustyJohnson']

# TENNESSEE
TN1 = ['DesJarlaisTN04','RepChuck','repdavidkustoff','SenAlexander','DrPhilRoe','RepTimBurchett','RepJohnRose',
       'RepMarkGreen','MarshaBlackburn']

# TEXAS
TX1 = ['JohnCornyn','RepKevinBrady','MichaelCBurgess','JudgeCarter','ConawayTX11','RepLouieGohmert','RepKayGranger',
       'RepMcCaul','RepBillFlores','SenTedCruz','TXRandy14','RepRWilliams','hurdonthehill','RepArrington',
       'RepCloudTX','RepDanCrenshaw','RepVanTaylor','RepLanceGooden','RepRonWright','RepChipRoy','RepRatcliffe'
      ,'RepBrianBabin','RepKenMarchant','RepPeteOlson','MacTXPress']

# UTAH
UT1 = ['SenatorRomney','SenMikeLee','RepJohnCurtis','RepRobBishop','RepChrisStewart']

# VERMONT
VT1 = []

# VIRGIN ISLANDS
VI1 = []
# VIRGINIA
VA1 = ['RepMGriffith','RepRiggleman','RepBenCline','RobWittman']

# WASHINGTON
WA1 = ['HerreraBeutler','CathyMcMorris','RepNewhouse']

# WEST VIRGINIA
WV1 = ['RepAlexMooney','SenCapito','RepMcKinley','RepCarolMiller']

# WISCONSIN
WI1 = ['RepSeanDuffy','SenRonJohnson','RepGrothman','RepGallagher','RepBryanSteil','JimPressOffice']

# WYOMING
WY1 = ['SenatorEnzi','RepLizCheney','SenJohnBarrasso']

# %%
Rep = AL1 +AK1+ AS1+ AZ1+ AR1+ CA1+ CO1+ CT1+ DE1+ DC1+ FL1+ GA1+ HI1+ ID1 +IL1+ IN1+ IA1+ KS1+ KY1+ LA1+ ME1+ MA1+ MI1+ MN1+ MS1+ MO1 +MT1 +NE1 +NV1 +NH1 +NJ1 +NM1 +NY1 +NC1 +ND1 +MP1 +OH1 +OK1+OR1 + PA1 + PR1+ RI1+ SC1+ SD1+ TN1+ TX1+ UT1+ VT1+ VI1+ VA1+ WA1+ WV1+ WI1+ WY1

# %%
len (Rep)
# Out:
# 246

# %%
import json

# %%
with open('Rep.json', 'w') as outfile:
    json.dump(Rep, outfile)

# %%
with open('Dems.json', 'w') as outfile:
    json.dump(Dems, outfile)
